# %% [markdown]
# # Fix pathing

# %%
import sys
sys.path.append("..")

import os
import constants

constants.PROJECT_DIRECTORY_PATH = os.path.dirname(os.path.dirname(constants.PROJECT_DIRECTORY_PATH))

# %% [markdown]
# # Init

# %%
import datahandler


dataset_id = "oslo"

data_preprocessor = datahandler.DataPreprocessorOUS(dataset_id)
data_preprocessor.execute()

data_loader = datahandler.DataLoader(dataset_id)
data_loader.execute()
# Out:
# Cleaning dataset: 100%|██████████| 2/2 [00:00<00:00, 3554.49it/s]
# Processing dataset: 100%|██████████| 2/2 [00:00<00:00, 3340.74it/s]
# Loading dataset: 100%|██████████| 4/4 [00:16<00:00,  4.09s/it]

# %% [markdown]
# # Plot

# %%
import matplotlib.pyplot as plt


nan_counts = data_loader.processed_incidents_df.isna().sum()
nan_counts = nan_counts[nan_counts > 0].sort_values(ascending=False)

nan_counts.plot(kind='bar', figsize=(10, 6))
plt.title('Number of NaN Values by Column')
plt.ylabel('Number of NaN Values')
plt.xlabel('Columns')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
