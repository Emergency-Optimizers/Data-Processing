# %% [markdown]
# # Fix pathing

# %%
import sys


sys.path.append("..")

# %%
import constants

import os


constants.PROJECT_DIRECTORY_PATH = os.path.dirname(os.path.dirname(constants.PROJECT_DIRECTORY_PATH))

# %% [markdown]
# # Init

# %%
import datahandler

import matplotlib.pyplot as plt


dataset_id = "oslo"

data_preprocessor = datahandler.DataPreprocessorOUS(dataset_id)
data_preprocessor.execute()

data_loader = datahandler.DataLoader(dataset_id)
data_loader.execute()
# Out:
# Cleaning dataset: 100%|██████████| 2/2 [00:00<00:00, 4054.43it/s]
# Processing dataset: 100%|██████████| 2/2 [00:00<00:00, 1727.83it/s]
# Enhancing dataset: 100%|██████████| 2/2 [00:00<00:00, 5559.05it/s]
# Loading dataset: 100%|██████████| 6/6 [01:01<00:00, 10.22s/it]

# %% [markdown]
# # Plot processed data

# %%
nan_counts = data_loader.processed_incidents_df.isna().sum()
nan_counts = nan_counts[nan_counts > 0].sort_values(ascending=False)

nan_counts.plot(kind='bar', figsize=(10, 6))
plt.title('Number of NaN Values by Column')
plt.ylabel('Number of NaN Values')
plt.xlabel('Columns')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Plot enhanced data

# %%
nan_counts = data_loader.enhanced_incidents_df.isna().sum()
nan_counts = nan_counts[nan_counts > 0].sort_values(ascending=False)

nan_counts.plot(kind='bar', figsize=(10, 6))
plt.title('Number of NaN Values by Column')
plt.ylabel('Number of NaN Values')
plt.xlabel('Columns')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
